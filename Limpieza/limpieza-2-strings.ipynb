# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sidetable

plt.rcParams["figure.figsize"] = (10,8)
pd.options.display.max_columns = None

# %%
df = pd.read_csv('../datos/df_bank_clean', index_col = 0)

# %%
df.sample(3)
# Out:
#        age            job   marital            education  default  housing  \
# 26427   31   entrepreneur    single          high.school      0.0      0.0
# 14459   42  self-employed  divorced             basic.6y      NaN      1.0
# 17317   54     technician   married  professional.course      0.0      0.0
#
#        loan    contact  duration  campaign  pdays  previous     poutcome  \
# 26427   0.0   cellular       290         1    999         0  nonexistent
# 14459   0.0   cellular        94         3    999         0  nonexistent
# 17317   1.0  telephone       395         6    999         0  nonexistent
#
#        emp,var,rate  cons,price,idx  cons,conf,idx  euribor3m  nr,employed  \
# 26427          -0.1          93.200          -42.0      4.076       5195.8
# 14459           1.4          93.918          -42.7      4.961       5228.1
# 17317           1.4          93.918          -42.7      4.962       5228.1
#
#         y  month_day_week
# 26427  no  ['nov', 'thu']
# 14459  no  ['jul', 'tue']
# 17317  no  ['jul', 'fri']

# %% [markdown]
# 1- Columnas loan, housing y default: estas columnas contienen valores únicos de 0 y 1. Esto puede parecer poco intuitivo a la hora de la extracción de conclusiones y en las visualizaciones.
# - El objetivo de este ejercicio es que cambies los valores númericos por "Si" y "No". A que corresponde cada uno de los valores lo tenéis en el pair de Limpieza I.

# %%
'''
def yes_no(x):
    if x == 0:
        return 'no'
    elif x == 1:
        return 'yes'
    else:
        return x
'''
# Out:
# "\ndef yes_no(x):\n    if x == 0:\n        return 'no'\n    elif x == 1:\n        return 'yes'\n    else:\n        return x\n"

# %%
mapa = {0 : 'no', 1 : 'yes'}

# %%
for col in ['loan', 'housing', 'default']:
    df[col] = df[col].map(mapa, na_action="ignore")

# %%
df.sample(3)
# Out:
#        age          job  marital          education default housing loan  \
# 23697   37       admin.  married  university.degree      no     yes   no
# 9766    35  blue-collar  married           basic.9y     NaN      no   no
# 38721   30       admin.   single  university.degree      no      no   no
#
#          contact  duration  campaign  pdays  previous     poutcome  \
# 23697   cellular        54         5    999         0  nonexistent
# 9766   telephone       579         4    999         0  nonexistent
# 38721   cellular       266         2    999         2      failure
#
#        emp,var,rate  cons,price,idx  cons,conf,idx  euribor3m  nr,employed  \
# 23697           1.4          93.444          -36.1      4.962       5228.1
# 9766            1.4          94.465          -41.8      4.961       5228.1
# 38721          -3.4          92.649          -30.1      0.715       5017.5
#
#          y  month_day_week
# 23697   no  ['aug', 'thu']
# 9766    no  ['jun', 'mon']
# 38721  yes  ['nov', 'tue']

# %% [markdown]
# 2- Para la columna de education, si nos fijamos en sus valores únicos veremos que tenemos puntos.
# - El objetivo de este ejercicio es que quitéis los puntos de esos valores y los reemplacéis por espacios.

# %%
df['education'] =df['education'].str.replace('.',' ')
# Out:
# /tmp/ipykernel_2080/3911354374.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['education'] =df['education'].str.replace('.',' ')

# %%
df.sample(3)
# Out:
#        age          job  marital            education default housing loan  \
# 4868    30   technician  married  professional course      no     yes   no
# 30534   35     services  married          high school      no      no   no
# 31099   39  blue-collar  married             basic 9y     NaN      no  yes
#
#          contact  duration  campaign  pdays  previous     poutcome  \
# 4868   telephone       265         1    999         0  nonexistent
# 30534   cellular       130         3    999         1      failure
# 31099   cellular       343         3    999         1      failure
#
#        emp,var,rate  cons,price,idx  cons,conf,idx  euribor3m  nr,employed  \
# 4868            1.1          93.994          -36.4      4.858       5191.0
# 30534          -1.8          92.893          -46.2      1.354       5099.1
# 31099          -1.8          92.893          -46.2      1.334       5099.1
#
#         y  month_day_week
# 4868   no  ['may', 'wed']
# 30534  no  ['may', 'mon']
# 31099  no  ['may', 'wed']

# %% [markdown]
# 3- Para la columna job, hay un valor único que esta abreviado (admin.), cambiad la abreviatura por el nombre completo.

# %%
df['job'].unique()
# Out:
# array(['housemaid', 'services', 'admin.', 'blue-collar', 'technician',
#        'retired', 'management', 'unemployed', 'self-employed', nan,
#        'entrepreneur', 'student'], dtype=object)

# %%
df['job'] =df['job'].str.replace('admin.','administration', regex = True)
# Out:
#        age          job  marital    education default housing loan    contact  \
# 9778    41   unemployed  married     basic 9y     NaN     yes   no  telephone
# 10241   31  blue-collar   single  high school      no     yes  yes  telephone
# 35418   25      student   single  high school      no     yes   no   cellular
#
#        duration  campaign  pdays  previous     poutcome  emp,var,rate  \
# 9778         80         3    999         0  nonexistent           1.4
# 10241       325         3    999         0  nonexistent           1.4
# 35418        59         2    999         0  nonexistent          -1.8
#
#        cons,price,idx  cons,conf,idx  euribor3m  nr,employed   y  \
# 9778           94.465          -41.8      4.961       5228.1  no
# 10241          94.465          -41.8      4.960       5228.1  no
# 35418          92.893          -46.2      1.244       5099.1  no
#
#        month_day_week
# 9778   ['jun', 'mon']
# 10241  ['jun', 'mon']
# 35418  ['may', 'mon']

# %%
df.sample(3)
# Out:
#        age             job  marital          education default housing loan  \
# 22928   47      technician  married        high school     NaN     yes  yes
# 26513   30  administration   single  university degree      no      no   no
# 33747   28     blue-collar   single        high school      no     yes   no
#
#         contact  duration  campaign  pdays  previous     poutcome  \
# 22928  cellular        89         2    999         0  nonexistent
# 26513  cellular        85         1    999         1      failure
# 33747  cellular       516         1    999         0  nonexistent
#
#        emp,var,rate  cons,price,idx  cons,conf,idx  euribor3m  nr,employed  \
# 22928           1.4          93.444          -36.1      4.965       5228.1
# 26513          -0.1          93.200          -42.0      4.076       5195.8
# 33747          -1.8          92.893          -46.2      1.281       5099.1
#
#          y  month_day_week
# 22928   no  ['aug', 'mon']
# 26513   no  ['nov', 'thu']
# 33747  yes  ['may', 'wed']

# %% [markdown]
# 4- La columna month_day_week tiene una lista que contiene información muy diferente.
# - El objetivo de este ejercicio es separar esta columna en dos nuevas, donde tengamos los meses en una columna y los días de la semana en otra.

# %%
df['month_day_week'].unique()
# Out:
# array(["['may', 'mon']", "['may', 'tue']", "['may', 'wed']",
#        "['may', 'thu']", "['may', 'fri']", "['jun', 'mon']",
#        "['jun', 'tue']", "['jun', 'wed']", "['jun', 'thu']",
#        "['jun', 'fri']", "['jul', 'tue']", "['jul', 'wed']",
#        "['jul', 'thu']", "['jul', 'fri']", "['jul', 'mon']",
#        "['aug', 'mon']", "['aug', 'tue']", "['aug', 'wed']",
#        "['aug', 'thu']", "['aug', 'fri']", "['oct', 'fri']",
#        "['oct', 'mon']", "['oct', 'tue']", "['oct', 'wed']",
#        "['oct', 'thu']", "['nov', 'mon']", "['nov', 'tue']",
#        "['nov', 'wed']", "['nov', 'thu']", "['nov', 'fri']",
#        "['dec', 'mon']", "['dec', 'wed']", "['dec', 'thu']",
#        "['dec', 'fri']", "['dec', 'tue']", "['mar', 'mon']",
#        "['mar', 'tue']", "['mar', 'wed']", "['mar', 'thu']",
#        "['mar', 'fri']", "['apr', 'wed']", "['apr', 'thu']",
#        "['apr', 'fri']", "['apr', 'mon']", "['apr', 'tue']",
#        "['sep', 'tue']", "['sep', 'wed']", "['sep', 'thu']",
#        "['sep', 'fri']", "['sep', 'mon']"], dtype=object)

# %%
# hacemos 3 replaces eliminando los elementos que nos sobran = "[" , "]" ,"'"
df['month_day_week'] = df['month_day_week'].str.replace("'", "")
df['month_day_week']
# Out:
# 0        may, mon
# 1        may, mon
# 2        may, mon
# 3        may, mon
# 4        may, mon
#            ...
# 41183    nov, fri
# 41184    nov, fri
# 41185    nov, fri
# 41186    nov, fri
# 41187    nov, fri
# Name: month_day_week, Length: 41176, dtype: object

# %%
df[['month', 'day_week']] = df['month_day_week'].str.split(',', expand = True, n = 1)

# %%
df.sample(3)
# Out:
#        age             job  marital          education default housing loan  \
# 18043   29  administration   single        high school      no      no   no
# 28436   40        services  married           basic 6y     NaN      no   no
# 2691    48  administration  married  university degree      no     yes  yes
#
#          contact  duration  campaign  pdays  previous     poutcome  \
# 18043  telephone        38         1    999         0  nonexistent
# 28436   cellular       140         2    999         2      failure
# 2691   telephone       160         1    999         0  nonexistent
#
#        emp,var,rate  cons,price,idx  cons,conf,idx  euribor3m  nr,employed  \
# 18043           1.4          93.918          -42.7      4.963       5228.1
# 28436          -1.8          93.075          -47.1      1.435       5099.1
# 2691            1.1          93.994          -36.4      4.859       5191.0
#
#         y month_day_week month day_week
# 18043  no       jul, wed   jul      wed
# 28436  no       apr, thu   apr      thu
# 2691   no       may, wed   may      wed

# %% [markdown]
# 5- Guarda el csv con las columnas limpias para seguir trabajando con este dataframe limpio.

# %%
df.to_csv('../datos/df_bank_clean2.csv')
